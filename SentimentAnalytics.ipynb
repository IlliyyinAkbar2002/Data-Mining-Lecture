# %% [markdown]
# <a href="https://colab.research.google.com/github/IlliyyinAkbar2002/Data-Mining-Lecture/blob/main/SentimentAnalytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="https://miro.medium.com/v2/resize:fit:1100/format:webp/1*9GrGYuorNbgCcITBkDhWvA.png" width="60%" align="left">

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-7d7ff42e-4b09-4b01-85e5-61e6233ad386" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7d7ff42e-4b09-4b01-85e5-61e6233ad386">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("Womens Clothing E-Commerce Reviews.csv")

# %%
import numpy as np
import nltk
nltk.download("vader_lexicon")

from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
df['Review Text'] = df['Review Text'].replace(np.nan, '', regex=True)

sentiment_scores = []
for text in df['Review Text']:
  scores = sid.polarity_scores(text)
  sentiment_scores.append(scores['compound'])

df['Sentiment Score'] = sentiment_scores

# %%
def get_sentiment_label(score):
  if score >= 0.05:
    return 'Positive'
  elif score <= -0.05:
    return 'Negative'
  else:
    return 'Neutral'

sentiment_labels = df['Sentiment Score'].apply(get_sentiment_label)

df['Senttiment Label'] = sentiment_labels

# %%
df.head(50)
# Out:
#     Unnamed: 0  Clothing ID  Age  \
# 0            0          767   33
# 1            1         1080   34
# 2            2         1077   60
# 3            3         1049   50
# 4            4          847   47
# 5            5         1080   49
# 6            6          858   39
# 7            7          858   39
# 8            8         1077   24
# 9            9         1077   34
# 10          10         1077   53
# 11          11         1095   39
# 12          12         1095   53
# 13          13          767   44
# 14          14         1077   50
# 15          15         1065   47
# 16          16         1065   34
# 17          17          853   41
# 18          18         1120   32
# 19          19         1077   47
# 20          20          847   33
# 21          21         1080   55
# 22          22         1077   31
# 23          23         1077   34
# 24          24          847   55
# 25          25          697   31
# 26          26          949   33
# ...

# %%
# @title Senttiment Label

from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('Senttiment Label').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
